# %%
from __future__ import print_function
__author__ = "Federica B. Bianco, CUSP NYU 2018"

# %% [markdown]
# # Create a <i>reproducible research</i> chunk of code
#
# That means we want the reader to be able to reproduce every step of the work we do.
#
# If our work includes the use of stochastic processes and random variables that gets tricky: how do we assure the random draw gives the same number to the user that it gave to me? That is not random!
#
# That becomes possible because computers are unable to poduce truly random numbers. When we ask a computer to generate a random number, it will in fact generate a "pseudo random" number. The number will be randon in the sanse that it will be some number between, for example, 0 and 1 if we ask for a **uniform random distribution** or a number near 0 if we aks for a **Gaussian distribution with mean 0**. <i> But the sequence of pseudo-random numbers that a compujter generates will depend on its **seed**: if you know the seed you know all the numbers that are "randomely" drawn</i>.
#
# You can read more about pseudorandom number generation in this wikipedia article https://en.wikipedia.org/wiki/Pseudorandom_number_generator
#
# Fill in the empty cells below with code, as directed.

# %%
import os
import sys

# you can use the numpy library for random number generation: 
# http://docs.scipy.org/doc/numpy/reference/routines.random.html

import numpy as np

# %% [markdown]
# ## THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ### give numpy as seed for this code to be reproducible
# (no points if this is wrong)
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
np.random.seed(seed=5)

# %% [markdown]
# ### 1. Generate random distributions. use the function
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html
# ### to generate 100 2-dimensional random datapoints in a gaussian distribution
#
# call the array ReprRand

# %%
ReprRand=np.random.randn(2,100)
print(ReprRand)
# Out:
# [[ 0.44122749 -0.33087015  2.43077119 -0.25209213  0.10960984  1.58248112
#   -0.9092324  -0.59163666  0.18760323 -0.32986996 -1.19276461 -0.20487651
#   -0.35882895  0.6034716  -1.66478853 -0.70017904  1.15139101  1.85733101
#   -1.51117956  0.64484751 -0.98060789 -0.85685315 -0.87187918 -0.42250793
#    0.99643983  0.71242127  0.05914424 -0.36331088  0.00328884 -0.10593044
#    0.79305332 -0.63157163 -0.00619491 -0.10106761 -0.05230815  0.24921766
#    0.19766009  1.33484857 -0.08687561  1.56153229 -0.30585302 -0.47773142
#    0.10073819  0.35543847  0.26961241  1.29196338  1.13934298  0.4944404
#   -0.33633626 -0.10061435  1.41339802  0.22125412 -1.31077313 -0.68956523
#   -0.57751323  1.15220477 -0.10716398  2.26010677  0.65661947  0.12480683
#   -0.43570392  0.97217931 -0.24071114 -0.82412345  0.56813272  0.01275832
#    1.18906073 -0.07359332 -2.85968797  0.7893664  -1.87774088  1.53875615
#    1.82136474 -0.42703139 -1.16470191 -1.39707402  0.87265462 -0.20211818
# ...

# %% [markdown]
# #### if you did this correctly the shape of ReprRand will be (2, 100)

# %%
# run this cell
ReprRand.shape
# Out:
# (2, 100)

# %% [markdown]
# ## 2. use the same function to generate 50 more random 2x100 numpy arrays and store them in ReprRandAll, all with different mean.
#
# np.random.randn creates a distribution with mean 0 and standard deviation 1 by default.
#
# To obtain a gaussian distribution with a mean different than 1 using np.random.randn you must add your new mean (it is explained in the dunction documentation for which I already gave you the link)
#
# If you want to change the standard deviation (sigma) as well you multiply the distribution by the new sigma.
#
# You can do it in a for loop. The first line of code I included generates an array of zeros that you can fill in with your new numbers.

# %%
ReprRandAll = np.zeros((50, 2, 100))

for i in range(50):
    ReprRandAll[i] = np.random.randn(2, 100) + (i+1)

print(ReprRandAll[0])
# Out:
# [[ 1.49961804 -0.15154425  0.3894836  -0.70388541  1.19443738  1.02824125
#    1.93256051  1.21204332  0.63205543  3.1114884  -0.02957349 -0.33628031
#    0.38943264  1.52469426  0.65069187  0.55926154 -0.1212876   2.47284473
#    0.37662776 -0.08070195  0.87746991  0.1922569   0.76744378  2.33515034
#    0.55354327  0.95021132  0.63145522  0.80826043  1.81967992  1.53163372
#    0.65838496  0.06909952  0.86578301  1.83259361  0.98264673  0.87234178
#   -0.80791662  1.99396898 -0.49112886 -0.28210748  0.62429259  1.03464388
#    1.04507816  0.23625311  0.68686149  0.39301046 -0.80955123  0.74448226
#    0.30620065  1.41919776  0.85479981  1.9638013   1.69622199  1.89940546
#    2.20837807  1.6932537   0.83363939  2.35311311  0.07137349  0.96452751
#    1.85964595  0.71250339  1.71494995  0.1965474   0.45951804  1.54617743
#    1.71188926  2.19715449  0.92993297  1.29822712  1.62619261  1.46743206
#   -0.30262143  0.42991035  2.44295001 -0.24399513  1.62888033  0.57440787
# ...

# %%
# run this cell
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %% [markdown]
# ## 3. now plot them:
#
# you can use the matplotlib library, and the function scatter(), but that would plot everything in the same color unless you ask it not to. For convenience, let's use the function plot() which by default plots lines, and tell it to plot points (in addition plot is actually more efficient, so if you have a large dataset you may want to consider using plot with points for it anyways)
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# http://matplotlib.org/users/pyplot_tutorial.html

# %%
import pylab as pl
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

# code here

# Scatter Plots:
for j in range(50):
    pl.plot(ReprRandAll[j][0], ReprRandAll[j][1], '.')

#name of plot
pl.title('Random Scatter Plots', fontsize=14)

# refers to the axes:
pl.ylabel('y-axis',fontsize=14)
pl.xlabel('x-axis',fontsize=14)
pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Always add a caption to each of your homework figures.
# And remember to give your labels some names!
# This is a general rule. Without the caption or axis labels this portion of the HW will not get points. Make sure the font in the labels is large enough to be readable.
#
# Caption 1:
# This plot "Random Scatter Plots" shows random scatter of 5000 points, which are composed of 50 random 2x100 arrays.And these arryas have a gaussian distribution with different deviation and mean.

# %% [markdown]
# ## Challenge
#
# It is easier to give the same mean and standard deviation to each dimension. Can you give two different values for the mean along the x- and the mean along the y- axis for each of the 50 distributions if you have not done so? If you are an experienced coder, can you do it in a single line?

# %%
# code here...

ReprRandX = np.zeros((50, 100))
ReprRandY = np.zeros((50, 100))

for i in range(50):
    ReprRandX[i] = (i+1) * np.random.randn(100) + (i+1)
for i in range(50):
    ReprRandY[i] = (i-1) * np.random.randn(100) + (i-1)

print(ReprRandX)
print(ReprRandY)
ReprRandX.shape
ReprRandY.shape
# Out:
# [[  -0.38212866    0.42863102    0.80163465 ...,    1.37731394
#      0.57543151    0.50978642]
#  [  -0.41632446    2.47835697    0.27049358 ...,    1.55899194
#      0.55113983    2.73319649]
#  [   4.95086632   -1.11435792   -1.22989344 ...,    2.70184629
#      7.15954923   -0.35233113]
#  ...,
#  [ 113.93708407   37.10848057   35.77469211 ...,   97.03845741
#     77.07641673   46.68076659]
#  [  34.02320898   62.3356071   102.72197743 ...,   38.5762285    16.76736746
#     78.37541214]
#  [ -22.05268952   18.81080338   17.68526483 ...,  -14.86695874
#    -40.42495595   27.49727587]]
# [[  5.51309421e-02  -1.79220505e+00   1.48598221e+00 ...,  -6.99792729e-01
#    -1.81237314e+00   5.83878950e-01]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  2.58614790e-01   1.12204055e+00  -1.00298995e+00 ...,   2.14461288e+00
#     8.29082529e-01   1.38007423e+00]
#  ...,
# ...

# %%
# plot here...

# Scatter Plots:
for h in range(50):
    pl.plot(ReprRandX[h],ReprRandY[h], '.')

#name of plot
pl.title('Random Scatter Plots 2', fontsize=14)

# refers to the axes:
pl.ylabel('y-axis',fontsize=14)
pl.xlabel('x-axis',fontsize=14)
pl.show()

# %% [markdown]
# Caption 2:
# This plot "Random Scatter Plots 2" shows another random scatter of 5000 points. In addition, Two different values are givenfor the mean along the x- and the mean along the y- axis for each of the 50 distributions.
